# %%
import pandas as pd

# %%
import numpy as np

# %%
import seaborn as sns

# %%
import matplotlib.pyplot as plt

# %%
dataset_1 = pd.read_csv(r"C:\Users\ACER\OneDrive\Desktop\DATASET1.csv")

# %%
dataset_1
# Out:
#      instant      dteday  season  yr  mnth  hr  holiday  weekday  weathersit  \
# 0          1  01-01-2011       1   0     1   0    False        6           1
# 1          2  01-01-2011       1   0     1   1    False        6           1
# 2          3  01-01-2011       1   0     1   2    False        6           1
# 3          4  01-01-2011       1   0     1   3    False        6           1
# 4          5  01-01-2011       1   0     1   4    False        6           1
# ..       ...         ...     ...  ..   ...  ..      ...      ...         ...
# 605      606  28-01-2011       1   0     1  11    False        5           3
# 606      607  28-01-2011       1   0     1  12    False        5           3
# 607      608  28-01-2011       1   0     1  13    False        5           3
# 608      609  28-01-2011       1   0     1  14    False        5           3
# 609      610  28-01-2011       1   0     1  15    False        5           2
#
#      temp
# 0    0.24
# 1    0.22
# ...

# %%
dataset_1 .info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 610 entries, 0 to 609
# Data columns (total 10 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   instant     610 non-null    int64
#  1   dteday      610 non-null    object
#  2   season      610 non-null    int64
#  3   yr          610 non-null    int64
#  4   mnth        610 non-null    int64
#  5   hr          610 non-null    int64
#  6   holiday     610 non-null    bool
#  7   weekday     610 non-null    int64
#  8   weathersit  610 non-null    int64
#  9   temp        610 non-null    float64
# dtypes: bool(1), float64(1), int64(7), object(1)
# memory usage: 43.6+ KB

# %%
dataset_1.head()
# Out:
#    instant      dteday  season  yr  mnth  hr  holiday  weekday  weathersit  \
# 0        1  01-01-2011       1   0     1   0    False        6           1
# 1        2  01-01-2011       1   0     1   1    False        6           1
# 2        3  01-01-2011       1   0     1   2    False        6           1
# 3        4  01-01-2011       1   0     1   3    False        6           1
# 4        5  01-01-2011       1   0     1   4    False        6           1
#
#    temp
# 0  0.24
# 1  0.22
# 2  0.22
# 3  0.24
# 4  0.24

# %%
missingvalues = dataset_1.isnull().sum()

# %%
missingvalues
# Out:
# instant       0
# dteday        0
# season        0
# yr            0
# mnth          0
# hr            0
# holiday       0
# weekday       0
# weathersit    0
# temp          0
# dtype: int64

# %%
duplicates= dataset_1.drop_duplicates()

# %%
duplicates
# Out:
#      instant      dteday  season  yr  mnth  hr  holiday  weekday  weathersit  \
# 0          1  01-01-2011       1   0     1   0    False        6           1
# 1          2  01-01-2011       1   0     1   1    False        6           1
# 2          3  01-01-2011       1   0     1   2    False        6           1
# 3          4  01-01-2011       1   0     1   3    False        6           1
# 4          5  01-01-2011       1   0     1   4    False        6           1
# ..       ...         ...     ...  ..   ...  ..      ...      ...         ...
# 605      606  28-01-2011       1   0     1  11    False        5           3
# 606      607  28-01-2011       1   0     1  12    False        5           3
# 607      608  28-01-2011       1   0     1  13    False        5           3
# 608      609  28-01-2011       1   0     1  14    False        5           3
# 609      610  28-01-2011       1   0     1  15    False        5           2
#
#      temp
# 0    0.24
# 1    0.22
# ...

# %%
sns.barplot(x='weekday', y='temp', data=dataset_1, height = 1, color = 'pink' )
plt.title('Bar Plot  ')
plt.show()

# %% [markdown]
# THE ABOVE BAR PLOT SHOWING RELATIONSHIP BETWEEN WEEKDAYS AND TEMPERATURE FLUCTUATION

# %%
dataset_2 = pd.read_csv (r"C:\Users\ACER\OneDrive\Desktop\DATASET 2.csv")

# %%
dataset_2
# Out:
#      Unnamed: 0  instant   atemp   hum  windspeed  casual  registered  cnt
# 0             0        1  0.2879  0.81     0.0000       3          13   16
# 1             1        2  0.2727  0.80     0.0000       8          32   40
# 2             2        3  0.2727  0.80     0.0000       5          27   32
# 3             3        4  0.2879  0.75     0.0000       3          10   13
# 4             4        5  0.2879  0.75     0.0000       0           1    1
# ..          ...      ...     ...   ...        ...     ...         ...  ...
# 605         605      606  0.2121  0.93     0.1045       0          30   30
# 606         606      607  0.2121  0.93     0.1045       1          28   29
# 607         607      608  0.2121  0.93     0.1045       0          31   31
# 608         608      609  0.2727  0.80     0.0000       2          36   38
# 609         609      610  0.2576  0.86     0.0000       1          40   41
#
# [610 rows x 8 columns]

# %%
dataset_2 .info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 610 entries, 0 to 609
# Data columns (total 8 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   Unnamed: 0  610 non-null    int64
#  1   instant     610 non-null    int64
#  2   atemp       599 non-null    float64
#  3   hum         610 non-null    float64
#  4   windspeed   610 non-null    float64
#  5   casual      610 non-null    int64
#  6   registered  610 non-null    int64
#  7   cnt         610 non-null    int64
# dtypes: float64(3), int64(5)
# memory usage: 38.3 KB

# %%
dataset_2.head()
# Out:
#    Unnamed: 0  instant   atemp   hum  windspeed  casual  registered  cnt
# 0           0        1  0.2879  0.81        0.0       3          13   16
# 1           1        2  0.2727  0.80        0.0       8          32   40
# 2           2        3  0.2727  0.80        0.0       5          27   32
# 3           3        4  0.2879  0.75        0.0       3          10   13
# 4           4        5  0.2879  0.75        0.0       0           1    1

# %%
missingvalues = dataset_2.isnull().sum()

# %%
missingvalues
# Out:
# Unnamed: 0     0
# instant        0
# atemp         11
# hum            0
# windspeed      0
# casual         0
# registered     0
# cnt            0
# dtype: int64

# %%
duplicates= dataset_2.drop_duplicates()

# %%
duplicates
# Out:
#      Unnamed: 0  instant   atemp   hum  windspeed  casual  registered  cnt
# 0             0        1  0.2879  0.81     0.0000       3          13   16
# 1             1        2  0.2727  0.80     0.0000       8          32   40
# 2             2        3  0.2727  0.80     0.0000       5          27   32
# 3             3        4  0.2879  0.75     0.0000       3          10   13
# 4             4        5  0.2879  0.75     0.0000       0           1    1
# ..          ...      ...     ...   ...        ...     ...         ...  ...
# 605         605      606  0.2121  0.93     0.1045       0          30   30
# 606         606      607  0.2121  0.93     0.1045       1          28   29
# 607         607      608  0.2121  0.93     0.1045       0          31   31
# 608         608      609  0.2727  0.80     0.0000       2          36   38
# 609         609      610  0.2576  0.86     0.0000       1          40   41
#
# [610 rows x 8 columns]

# %%
sns.boxplot(x= 'hum', y='cnt', data=dataset_2,color = 'blue' )
plt.title('Box Plot')
plt.show()

# %% [markdown]
# above box plot showing relationship between cnt and hum

# %%
merged = pd.merge (dataset_1 , dataset_2 ,on = 'instant' , how= 'inner')

# %%
merged
# Out:
#      instant      dteday  season  yr  mnth  hr  holiday  weekday  weathersit  \
# 0          1  01-01-2011       1   0     1   0    False        6           1
# 1          2  01-01-2011       1   0     1   1    False        6           1
# 2          3  01-01-2011       1   0     1   2    False        6           1
# 3          4  01-01-2011       1   0     1   3    False        6           1
# 4          5  01-01-2011       1   0     1   4    False        6           1
# ..       ...         ...     ...  ..   ...  ..      ...      ...         ...
# 605      606  28-01-2011       1   0     1  11    False        5           3
# 606      607  28-01-2011       1   0     1  12    False        5           3
# 607      608  28-01-2011       1   0     1  13    False        5           3
# 608      609  28-01-2011       1   0     1  14    False        5           3
# 609      610  28-01-2011       1   0     1  15    False        5           2
#
# ...

# %%
missingvalues = merged.isnull().sum()

# %%
missingvalues
# Out:
# instant        0
# dteday         0
# season         0
# yr             0
# mnth           0
# hr             0
# holiday        0
# weekday        0
# weathersit     0
# temp           0
# Unnamed: 0     0
# atemp         11
# hum            0
# windspeed      0
# casual         0
# registered     0
# cnt            0
# dtype: int64

# %%
merged
# Out:
#      instant      dteday  season  yr  mnth  hr  holiday  weekday  weathersit  \
# 0          1  01-01-2011       1   0     1   0    False        6           1
# 1          2  01-01-2011       1   0     1   1    False        6           1
# 2          3  01-01-2011       1   0     1   2    False        6           1
# 3          4  01-01-2011       1   0     1   3    False        6           1
# 4          5  01-01-2011       1   0     1   4    False        6           1
# ..       ...         ...     ...  ..   ...  ..      ...      ...         ...
# 605      606  28-01-2011       1   0     1  11    False        5           3
# 606      607  28-01-2011       1   0     1  12    False        5           3
# 607      608  28-01-2011       1   0     1  13    False        5           3
# 608      609  28-01-2011       1   0     1  14    False        5           3
# 609      610  28-01-2011       1   0     1  15    False        5           2
#
# ...

# %%
sns.barplot(x='weekday', y='temp', data=merged, height = 1, color = 'yellow' )
plt.title('Bar Plot  ')
plt.show()

# %% [markdown]
# above barplot showing  merrged dataset temp and  weekdays correlation

# %%
merged['temp'].mean ()
# Out:
# 0.19688524590163933

# %%
merged['temp'].median ()
# Out:
# 0.2

# %%
merged['temp'].mode ()
# Out:
# 0    0.2
# Name: temp, dtype: float64

# %%
merged['casual'].mean ()
# Out:
# 4.501639344262295

# %%
merged['casual'].median ()
# Out:
# 2.0

# %%
merged['casual'].mode ()
# Out:
# 0    0
# Name: casual, dtype: int64

# %%
merged.drop_duplicates()
# Out:
#      instant      dteday  season  yr  mnth  hr  holiday  weekday  weathersit  \
# 0          1  01-01-2011       1   0     1   0    False        6           1
# 1          2  01-01-2011       1   0     1   1    False        6           1
# 2          3  01-01-2011       1   0     1   2    False        6           1
# 3          4  01-01-2011       1   0     1   3    False        6           1
# 4          5  01-01-2011       1   0     1   4    False        6           1
# ..       ...         ...     ...  ..   ...  ..      ...      ...         ...
# 605      606  28-01-2011       1   0     1  11    False        5           3
# 606      607  28-01-2011       1   0     1  12    False        5           3
# 607      608  28-01-2011       1   0     1  13    False        5           3
# 608      609  28-01-2011       1   0     1  14    False        5           3
# 609      610  28-01-2011       1   0     1  15    False        5           2
#
# ...

# %%
dataset_3 = pd.read_csv(r"C:\Users\ACER\OneDrive\Desktop\DATASET 3.csv")

# %%
dataset_3
# Out:
#      instant      dteday  season  yr  mnth  hr  holiday  weekday  weathersit  \
# 0        620  29-01-2011       1   0     1   1    False        6           1
# 1        621  29-01-2011       1   0     1   2    False        6           1
# 2        622  29-01-2011       1   0     1   3    False        6           1
# 3        623  29-01-2011       1   0     1   4    False        6           1
# 4        624  29-01-2011       1   0     1   6    False        6           1
# ..       ...         ...     ...  ..   ...  ..      ...      ...         ...
# 385      615  28-01-2011       1   0     1  20    False        5           2
# 386      616  28-01-2011       1   0     1  21    False        5           2
# 387      617  28-01-2011       1   0     1  22    False        5           1
# 388      618  28-01-2011       1   0     1  23    False        5           1
# 389      619  29-01-2011       1   0     1   0    False        6           1
#
# ...

# %%
dataset_3.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 390 entries, 0 to 389
# Data columns (total 16 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   instant     390 non-null    int64
#  1   dteday      390 non-null    object
#  2   season      390 non-null    int64
#  3   yr          390 non-null    int64
#  4   mnth        390 non-null    int64
#  5   hr          390 non-null    int64
#  6   holiday     390 non-null    bool
#  7   weekday     390 non-null    int64
#  8   weathersit  390 non-null    int64
#  9   temp        390 non-null    float64
#  10  atemp       390 non-null    float64
#  11  hum         390 non-null    float64
#  12  windspeed   390 non-null    float64
#  13  casual      390 non-null    int64
#  14  registered  390 non-null    int64
#  15  cnt         390 non-null    int64
# dtypes: bool(1), float64(4), int64(10), object(1)
# memory usage: 46.2+ KB

# %%
dataset_3.head()
# Out:
#    instant      dteday  season  yr  mnth  hr  holiday  weekday  weathersit  \
# 0      620  29-01-2011       1   0     1   1    False        6           1
# 1      621  29-01-2011       1   0     1   2    False        6           1
# 2      622  29-01-2011       1   0     1   3    False        6           1
# 3      623  29-01-2011       1   0     1   4    False        6           1
# 4      624  29-01-2011       1   0     1   6    False        6           1
#
#    temp   atemp   hum  windspeed  casual  registered  cnt
# 0  0.22  0.2273  0.64     0.1940       0          20   20
# 1  0.22  0.2273  0.64     0.1642       0          15   15
# 2  0.20  0.2121  0.64     0.1343       3           5    8
# 3  0.16  0.1818  0.69     0.1045       1           2    3
# 4  0.16  0.1818  0.64     0.1343       0           2    2

# %% [markdown]
# SCATTER PLOT

# %%
sns.scatterplot(data=dataset_3 ,x='temp',y='cnt')
# Out:
# <Axes: xlabel='temp', ylabel='cnt'>

# %%
final_dataset = pd.concat([merged,dataset_3],axis=0)

# %%
final_dataset
# Out:
#      instant      dteday  season  yr  mnth  hr  holiday  weekday  weathersit  \
# 0          1  01-01-2011       1   0     1   0    False        6           1
# 1          2  01-01-2011       1   0     1   1    False        6           1
# 2          3  01-01-2011       1   0     1   2    False        6           1
# 3          4  01-01-2011       1   0     1   3    False        6           1
# 4          5  01-01-2011       1   0     1   4    False        6           1
# ..       ...         ...     ...  ..   ...  ..      ...      ...         ...
# 385      615  28-01-2011       1   0     1  20    False        5           2
# 386      616  28-01-2011       1   0     1  21    False        5           2
# 387      617  28-01-2011       1   0     1  22    False        5           1
# 388      618  28-01-2011       1   0     1  23    False        5           1
# 389      619  29-01-2011       1   0     1   0    False        6           1
#
# ...

# %%
final_dataset = final_dataset.loc[:, ~final_dataset.columns.str.contains('^Unnamed')]

# %%
final_dataset
# Out:
#      instant      dteday  season  yr  mnth  hr  holiday  weekday  weathersit  \
# 0          1  01-01-2011       1   0     1   0    False        6           1
# 1          2  01-01-2011       1   0     1   1    False        6           1
# 2          3  01-01-2011       1   0     1   2    False        6           1
# 3          4  01-01-2011       1   0     1   3    False        6           1
# 4          5  01-01-2011       1   0     1   4    False        6           1
# ..       ...         ...     ...  ..   ...  ..      ...      ...         ...
# 385      615  28-01-2011       1   0     1  20    False        5           2
# 386      616  28-01-2011       1   0     1  21    False        5           2
# 387      617  28-01-2011       1   0     1  22    False        5           1
# 388      618  28-01-2011       1   0     1  23    False        5           1
# 389      619  29-01-2011       1   0     1   0    False        6           1
#
# ...

# %%
final_dataset = final_dataset.dropna(axis=1)

# %%
final_dataset
# Out:
#      instant      dteday  season  yr  mnth  hr  holiday  weekday  weathersit  \
# 0          1  01-01-2011       1   0     1   0    False        6           1
# 1          2  01-01-2011       1   0     1   1    False        6           1
# 2          3  01-01-2011       1   0     1   2    False        6           1
# 3          4  01-01-2011       1   0     1   3    False        6           1
# 4          5  01-01-2011       1   0     1   4    False        6           1
# ..       ...         ...     ...  ..   ...  ..      ...      ...         ...
# 385      615  28-01-2011       1   0     1  20    False        5           2
# 386      616  28-01-2011       1   0     1  21    False        5           2
# 387      617  28-01-2011       1   0     1  22    False        5           1
# 388      618  28-01-2011       1   0     1  23    False        5           1
# 389      619  29-01-2011       1   0     1   0    False        6           1
#
# ...

# %%
final_dataset.to_csv(r"C:\Users\ACER\OneDrive\Desktop\final\finaldataset.csv", index= False )

# %%
final_dataset.to_excel(r"C:\Users\ACER\OneDrive\Desktop\final\finaldataset.xlsx", index= False )

# %%
missing_values = final_dataset.isnull().sum()

# %%
missing_values
# Out:
# instant       0
# dteday        0
# season        0
# yr            0
# mnth          0
# hr            0
# holiday       0
# weekday       0
# weathersit    0
# temp          0
# hum           0
# windspeed     0
# casual        0
# registered    0
# cnt           0
# dtype: int64

# %%
for col in ['temp', 'hum','windspeed','casual','registered','cnt']:
    q1= final_dataset [col].quantile(0.25)
    q3= final_dataset [col].quantile(0.75)
    iqr =q3-q1 
    lower_bound =q1-1.5 *iqr
    upper_bound = q3 + 1.5 *iqr

# %%
final_dataset[col]= np.clip(final_dataset[col],lower_bound,upper_bound)

# %%
final_dataset[col]
# Out:
# 0      16.0
# 1      40.0
# 2      32.0
# 3      13.0
# 4       1.0
#        ...
# 385    62.0
# 386    58.0
# 387    26.0
# 388    23.0
# 389    28.0
# Name: cnt, Length: 1000, dtype: float64

# %%
plt.figure(figsize=(4, 3))
sns.violinplot(x=['final_dataset[col]','values'])
plt.title('Violin Plot to Detect Outliers')
plt.show()

# %%
final_dataset.shape
# Out:
# (1000, 13)

# %%
numerical_cols= ['temp','hum','windspeed','cnt']

# %%
for col in numerical_cols:
    if final_dataset[col].skew()>0.5 or final_dataset[col].skew()<-0.5:
        final_dataset[col] = np.log1p(final_dataset[col])

# %%
final_dataset[col] = np.log1p(final_dataset[col])

# %%
final_dataset[col]
# Out:
# 0      1.343703
# 1      1.550446
# 2      1.503301
# 3      1.291725
# 4      0.526589
#          ...
# 385    1.637663
# 386    1.624826
# 387    1.457646
# 388    1.429846
# 389    1.474144
# Name: cnt, Length: 1000, dtype: float64

# %%
from scipy.stats import skew 
import numpy as np  
import pylab as p  
  
x1 = np.linspace( -5, 5, ) 
y1 = 1./(np.sqrt(2.*np.pi)) * np.exp( -.5*(x1)**2  ) 
  
p.plot(x1, y1, '*') 
  
print( '\nSkewness for data : ', skew(y1))
# Out:
# Skewness for data :  1.1388370497042246

# %%
sns.scatterplot(data=final_dataset ,x='temp',y='cnt')
# Out:
# <Axes: xlabel='temp', ylabel='cnt'>

# %%
sns.boxplot(data=final_dataset [['temp','cnt']])
# Out:
# <Axes: >

# %%
final_dataset.describe
# Out:
# <bound method NDFrame.describe of      instant  season  mnth  hr  holiday  weekday  weathersit      temp   hum  \
# 0          1       1     1   0    False        6           1  0.215111  0.81
# 1          2       1     1   1    False        6           1  0.198851  0.80
# 2          3       1     1   2    False        6           1  0.198851  0.80
# 3          4       1     1   3    False        6           1  0.215111  0.75
# 4          5       1     1   4    False        6           1  0.215111  0.75
# ..       ...     ...   ...  ..      ...      ...         ...       ...   ...
# 385      615       1     1  20    False        5           2  0.215111  0.70
# 386      616       1     1  21    False        5           2  0.198851  0.75
# 387      617       1     1  22    False        5           1  0.215111  0.65
# 388      618       1     1  23    False        5           1  0.215111  0.60
# 389      619       1     1   0    False        6           1  0.198851  0.64
#
# ...

# %%
correlation_matrix= final_dataset.corr()

# %%
correlation_matrix
# Out:
#              instant  season      mnth        hr   holiday   weekday  \
# instant     1.000000     NaN  0.802477  0.000060 -0.063013  0.008157
# season           NaN     NaN       NaN       NaN       NaN       NaN
# mnth        0.802477     NaN  1.000000 -0.025646 -0.105600  0.034710
# hr          0.000060     NaN -0.025646  1.000000 -0.005753  0.007531
# holiday    -0.063013     NaN -0.105600 -0.005753  1.000000 -0.148682
# weekday     0.008157     NaN  0.034710  0.007531 -0.148682  1.000000
# weathersit  0.030439     NaN  0.014061 -0.055802  0.165443  0.060007
# temp        0.025092     NaN  0.161460  0.207257 -0.056316 -0.078685
# hum         0.062116     NaN  0.066587 -0.194853 -0.037542  0.062469
# windspeed  -0.057837     NaN -0.029383  0.116640 -0.001111 -0.056754
# casual      0.071259     NaN  0.088326  0.204476 -0.000944 -0.047363
# registered  0.074993     NaN  0.072660  0.357042 -0.054350  0.020505
# cnt         0.056319     NaN  0.036698  0.571741 -0.031877  0.045804
#
# ...

# %%
plt.matshow(final_dataset.corr())
plt.show()

# %%
plt.figure(figsize=(7,3))
sns.heatmap(correlation_matrix, cmap= 'coolwarm')
set_title =("heatmap")
plt.show()
